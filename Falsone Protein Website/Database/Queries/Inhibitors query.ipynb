# %%
from sqlalchemy import create_engine
from sqlalchemy.orm import sessionmaker
engine=create_engine("sqlite:///1.7 -funtional.db")#,echo=True)
Session=sessionmaker(bind=engine)
session=Session()

from sqlalchemy import MetaData, Table
metadata = MetaData()
alt_names=Table('Alt_names', metadata, autoload=True, autoload_with=engine)
inhibitor=Table('Inhibitor',metadata,autoload=True,autoload_with=engine)
kinase=Table('Kinase',metadata,autoload=True,autoload_with=engine)
kinase_inhibitor=Table('Kinase_Inhibitor',metadata,autoload=True,autoload_with=engine)
sub_phos=Table('Substrate_phosphosite',metadata,autoload=True,autoload_with=engine)
substrate_kinase=Table('Substrate_site_Kinase',metadata,autoload=True,autoload_with=engine)
substrate=Table('Substrate',metadata,autoload=True,autoload_with=engine)
# Out:
# C:\Users\44771\Anaconda3\lib\site-packages\sqlalchemy\dialects\sqlite\base.py:1297: SAWarning: Could not instantiate type <class 'sqlalchemy.sql.sqltypes.INTEGER'> with reflected arguments ['3']; using no arguments.
#   (coltype, args))
# C:\Users\44771\Anaconda3\lib\site-packages\sqlalchemy\dialects\sqlite\base.py:1297: SAWarning: Could not instantiate type <class 'sqlalchemy.sql.sqltypes.INTEGER'> with reflected arguments ['7']; using no arguments.
#   (coltype, args))
# C:\Users\44771\Anaconda3\lib\site-packages\sqlalchemy\dialects\sqlite\base.py:1297: SAWarning: Could not instantiate type <class 'sqlalchemy.sql.sqltypes.INTEGER'> with reflected arguments ['5']; using no arguments.
#   (coltype, args))

# %%
search=input("Enter an inhibitor name: ")
search1="%"+search+"%"
inhib=session.query(inhibitor).filter(inhibitor.c.Inhibitor_name.like(search1)).all()
for x in inhib:
    print(x.Inhibitor_name)
# Out:
# Enter an inhibitor name: i
# 1 NM-PP1 (PP1 Analog II)
# AG879 (Tyrphostin)
# Akti 1/2
# AS601245 (JNK Inhibitor V)
# BAY439006 (Sorafenib/ Nexavar)
# BI 2536
# BI-D-1870
# BIO (6-Bromoindirubin-3'-oxime)
# BIRB-0796 (Doramapimod)
# Blebbistatin
# BMS345541 (IKK Inhibitor III)
# Chelerythrine Chloride
# CHIR 99021 (CT 99021)
# CKI-7
# Compound C (Dorsomorphin)
# Curcumin
# EGCG (Epigallocatechin Gallate)
# FMK (Caspase Inhibitor I)
# Genistein
# Gleevec (Imatinib)
# GW5074 (Raf1 Kinase Inhibitor I)
# H-1152 (Rho Kinase Inhibitor)
# H-7/ Dihydrochloride
# H-8/ Dihydrochloride
# H-89/ Dihydrochloride
# HA-1077/ Dihydrochloride (Fasudil)
# Harmaline
# Harmine
# IC261
# IKK-2 Inhibitor IV (TPCA-1)
# IKK-3 inhibitor IX
# IRAK-4 kinase inhibitor a
# LiCl
# LY333531 (Ruboxistaurin)
# ML-7/ Hydrochloride
# ML-9/ Hydrochloride
# Necrostatin-1 (Nec-1)
# Nectrostatin-1 (Nec-1 inactive analog)
# PD 0325901-Cl (CI-1055-S)
# PD 184352 (CI-1040)
# PI-103
# Piceatannol
# Pirfenidone
# PLX 4720 (Raf Kinase Inhibitor V)
# Princeton's TrkA inhibitor compound 20h
# Rapamycin
# Roscovitine
# Rottlerin
# SC514 ( IKK-2 Inhibitor)
# SL-327 (MEK1-2 Inhibitor)
# Sodium valproate
# SP600125 (JNK Inhibitor II/  SAPK Inhibitor II)
# SRC Inhibitor 1
# SU-5416 (VEGFR2 Kinase Inhibitor III)
# Wortmannin (KY 12420)
# Wyeth PDK1 Inhibitor Compound 1
# BI-78D3
# IPA-3
# Cot-Tpl2 Inhibitor Compound 41 (Abbott)
# Caffeine
# Cot-Tpl2 Inhibitor Compound 38 (Abbott)
# SYK Inhibitor I
# SYK Inhibitor II
# SYK Inhibitor III
# SYK Inhibitor IV (BAY 61-3606)
# AG1296 (Tyrphostin)
# IRAK 1-4 Inhibitor 1
# HA-1100 (Hydroxyfasudil)
# Akt Inhibitor IV
# Sunitinib (SU-11248)
# AG1478 (Tyrphostin)
# Sulfasalazine
# Quercetagetin
# Cot-Tpl2 Inhibitor Compound 10b (Abbott)
# IMD-0354
# IKK Inhibitor VII
# IKK-2 Inhibitor VIII
# Rigel TRAF6 Inhibitor
# BML-258 (SK1-I)
# Sphingosine Kinase Inhibitor (SKI II)
# LRRK2-IN1
# Sodium salicylate
# Ruxolitinib (INCB18424)
# Febuxostat (TMX-67/ Adenuric/ Uloric)
# BI605906 (BIX02514)
# CP-690550 (Tasocitinib)
# Ubiquitin E1 Inhibitor (PYR-41)
# GW441756 hydrochloride
# Staurosporine
# PCI-32765 (Ibrutinib)
# PD 0325901-Cl (CI-1055-R)
# PD 0325901-Cl (CI-1055-Racemic mix of isomers)
# Novartis 12a (PKD1)
# Amgen TBK 1 inhibitor (Compound II)
# Ischemin
# PLX 4032 (Vemurafenib)
# KIN 112
# JNKIN7
# JNKIN8
# Hypothemycin
# IRAK-4 kinase inhibitor b
# Torin1
# Saracatinib (AZD0530)
# Dimethyl fumarate
# Lenalidomide (Revlimid)
# Withaferin A
# Parthenolide
# Genentech LRRK2 inhibitor compound 18 (GNE-7915)
# Genentech LRRK2 inhibitor compound 19
# Kalopanaxsaponin A
# 2-Aminopurine
# PKR Inhibitor
# Leflunomide
# Chloroquine
# Amgen-NIK-28
# Fostamatinib
# Tenovin-6
# VPS34-IN2 (PIK-III)
# Metformin
# Dasatinib
# Bosutinib
# VPS34-IN1
# Volasertib
# Crenolanib
# SGK1-Sanofi-14g
# SGK-Sanofi-14i
# SGK1-Sanofi-14n
# SGK1-Sanofi-14h
# MLi-2
# SGK1-Sanofi-308-R
# SGK1-Sanofi-308-S
# NIK-Novartis-T1-7
# SGK1-Sanofi-ex.290-S
# SGK1-Sanofi-ex.290-R
